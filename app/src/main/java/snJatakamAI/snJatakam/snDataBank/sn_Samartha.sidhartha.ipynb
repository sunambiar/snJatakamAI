# %%
#!pip install requests
#!pip install BeautifulSoup4

mypath = '/Users/sureshnambiar/Desktop/Python/astrology/jyotisha-master/'

import pandas as pd
import requests
from bs4 import BeautifulSoup

#-- category and no. of pages
segments = {'businessman':4, 'politician':9, 'cricket':9, 'hollywood':9, 'bollywood':9, 'musician':9, 'literature':9, 'sports':9, 'criminal':2, 'astrologer':7, 'singer':9, 'scientist':1, 'football':9, 'hockey':2 }

names_url_part = {}
for i in segments:
  names_href = []
  for j in range(segments[i]):
    url = 'http://www.astrosage.com/celebrity-horoscope/default.asp?page='+str(j+1)+"&category="+str(i)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    for row in soup.find_all(class_ = 'ui-img-container'):
      names_href.append(row.a['href'])
  names_url_part[str(i)] = names_href


m = pd.DataFrame.from_dict(names_url_part, orient='index')
m = m.transpose()
m.to_csv(mypath + "snJyotish_links.csv", index="Name")

display(m)
# Out:
#                             businessman  \
# 0            donald-trump-horoscope.asp
# 1    vijay-shekhar-sharma-horoscope.asp
# 2               jay-mehta-horoscope.asp
# 3            mohit-burman-horoscope.asp
# 4            akash-ambani-horoscope.asp
# ..                                  ...
# 175                                None
# 176                                None
# 177                                None
# 178                                None
# 179                                None
#
#                                   politician                         cricket  \
# 0                  pawan-khera-horoscope.asp      yograj-singh-horoscope.asp
# 1             innocent-vincent-horoscope.asp        imran-khan-horoscope.asp
# 2              anubhav-mohanty-horoscope.asp       mithali-raj-horoscope.asp
# 3                  sanjay-raut-horoscope.asp        ben-stokes-horoscope.asp
# 4                   imran-khan-horoscope.asp      anjum-chopra-horoscope.asp
# ...

# %%
#========================
import time
dyt={
	'Date of Birth':[],
	'Information Source':[],
	'Latitude':[],
	'Longitude':[],
	'Name':[],
	'Place of Birth':[],
	'Segment':[],
	'Time Zone':[],
	'Time of Birth':[]
	}

cnt = 1
totalTimeStart = time.time()
totalTimeEnd = time.time()
for l in names_url_part:
   for j in names_url_part[str(l)]:
     #https://celebrity.astrosage.com/donald-trump-horoscope.asp
     #url = "https://celebrity.astrosage.com/celebrity-horoscope/" + str(j)
     if len(str(j)) <= 0:
        continue
     url = "http://www.astrosage.com/celebrity-horoscope/" + str(j)
     #print(url)
     start = time.time()
     try:
       response = requests.get(url)
     except:
       continue
     soup = BeautifulSoup(response.content, 'html.parser')
     for row in soup.find_all(class_ = 'celebcont', limit=8):
       try:
          #print(str(row.b.contents[0]).strip(":"))
          #print(str(row.contents[2]).strip())
          dyt[str(row.b.contents[0]).strip(":")].append(str(row.contents[2]).strip())
       except:
          continue
     dyt['Segment'].append(str(l))
     end = time.time() 
     print(str(cnt) + ":" + str(end - start))
     cnt = cnt + 1
     totalTimeEnd = totalTimeEnd + (end - start)
     #if cnt > 20000:
     #   break
   #if cnt > 20000:
     #break
        
print("Total Time taken = " + str(totalTimeEnd - totalTimeStart))     

mDtl = pd.DataFrame.from_dict(dyt, orient='index')
mDtl = mDtl.transpose()
mDtl.to_csv(mypath + "snJyotish_charts.csv", index="Name")
display(mDtl)
# Out:
# 1:0.7399280071258545
# 2:0.5893681049346924
# 3:0.918931245803833
# 4:0.6112041473388672
# 5:0.5473997592926025
# 6:0.6178550720214844
# 7:0.5571250915527344
# 8:0.7485239505767822
# 9:0.548759937286377
# 10:0.879828929901123
# 11:1.1014740467071533
# 12:0.8661997318267822
# 13:0.6502611637115479
# 14:0.5377483367919922
# 15:0.6910629272460938
# 16:0.636199951171875
# 17:0.6411020755767822
# 18:0.563011884689331
# 19:0.5358948707580566
# 20:0.5400400161743164
# 21:0.6519379615783691
# 22:0.5950090885162354
# 23:0.6553878784179688
# 24:0.6314003467559814
# 25:0.5170140266418457
# 26:2.018371105194092
# 27:0.5491888523101807
# 28:0.6052379608154297
# 29:1.128187894821167
# 30:0.6288557052612305
# 31:1.7745137214660645
# 32:0.7859969139099121
# 33:0.659437894821167
# 34:0.5140011310577393
# 35:0.6361041069030762
# 36:0.688633918762207
# 37:0.7279808521270752
# 38:0.8983438014984131
# 39:0.6288108825683594
# 40:0.5321428775787354
# 41:0.5899138450622559
# 42:0.6503298282623291
# ...

# %%
mDt0 = pd.DataFrame.from_dict(dyt['Segment'], orient='index')
mDt0 = mDt0.transpose()
#mDt0.to_csv(mypath + "snJyotish_charts.csv", index="Name")
display(mDtl)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-806a86b3a5b1> in <module>
# ----> 1 mDt0 = pd.DataFrame.from_dict(dyt['Segment'], orient='index')
#       2 mDt0 = mDt0.transpose()
#       3 #mDt0.to_csv(mypath + "snJyotish_charts.csv", index="Name")
#       4 display(mDtl)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1297             if len(data) > 0:
#    1298                 # TODO speed up Series case
# -> 1299                 if isinstance(list(data.values())[0], (Series, dict)):
#    1300                     data = _from_nested_dict(data)
#    1301                 else:
#
# AttributeError: 'list' object has no attribute 'values'

# %%
class DMS:
    
  deg = float(0.0)
  html = False
  
  #constructor
  def __init__(self, d, html) :
    self.deg = d
    self.html = html

  @staticmethod
  def dms(d) : 
    d = float(d)
    sgn = ""
    if d < 0 :
      sgn = '-'
      d = -d
    deg = d
    dd = int(d)
    d = (d - int(d)) * 60 
    mm = int(d)
    d = round(d - int(d)) * 60
    ss = int(d)
    if ss >= 60:
      ss -= 60
      mm += 1
    if mm >= 60:
      mm -= 60
      dd += 1
    if dd >= 360:
      dd -= 360 
    strfmt = "{}{}{}{}'{}" + '"' 
    return (strfmt.format(sgn.strip(), dd, "&deg;" if DMS.html else "\u00B0", mm, ss))
    #return (strfmt.format(sgn.strip(), dd, "&deg;" if DMS.html else "�", mm, ss))



if __name__ == "__main__":
  print(DMS.dms(240.54234))
# Out:
# 240°33'0"

# %%
#!pip3 install multipledispatch 
from multipledispatch import dispatch 

class HMS:
    
  hrs = float(0.0) 
  
  #constructor
  def __init__(self, h) :
    self.hrs = h 

  @staticmethod
  @dispatch(float)
  def hms(h) :
    return HMS.hms(h, False)

  @staticmethod
  @dispatch(float, bool)
  def hms(h, hr24) :
    sgn = ''
    if not hr24 :
      if h > 24.0 :
        h -= 24 * (int(h / 24))
      if h < 0 :
        sgn = '-'
        h = -h
      hrs = h
      hh = int(h)
      h = (h - int(h)) * 60
      mm = int(h)
      h = (h - int(h)) * 60
      ss = round(h)
      if ss >= 60 :
        ss -= 60
        mm += 1
      if mm >= 60 :
        mm -= 60
        hh += 1
      if hr24 :
        ampm = 'hrs'
      else :
        if hh >= 24 :
          hh -= 24
        if hh > 12 :
          hh -= 12
          ampm = 'PM'
        else :
          if (hh + (mm + ss / 60.0) / 60.0) > 12.0 :
            ampm = 'PM'
          else :
            ampm = 'AM'
    strfmt = "{}{}:{}:{} {}"
    return (strfmt.format(sgn.strip(), hh, mm, ss, ampm)) 



if __name__ == "__main__":
  print(HMS.hms(26.54234))
# Out:
# 2:32:32 AM

# %%
  def JD2CAL(jd) :
    #long j1, j2, j3, j4, j5;      //scratch

    #//
    #// get the date from the Julian day number
    #//
    intgr = int(jd // 1)
    frac = jd - intgr
    gregjd = 2299161
    if (intgr >= gregjd) :      # //Gregorian calendar correction
      tmp = int(((((intgr - 1867216) - 0.25) // 1) / 36524.25)
      j1 = intgr + 1 + tmp - int((0.25 * tmp) // 1)
    else :
      j1 = intgr
  
    #//correction for half day offset
    dayfrac = frac + 0.5
    if (dayfrac >= 1.0) :
      dayfrac -= 1.0
      j1 += 1

    j2 = j1 + 1524
    j3 = int((6680.0 + ((j2 - 2439870) - 122.1) / 365.25) // 1)
    j4 = int((j3 * 365.25) // 1)
    j5 = int(((j2 - j4) / 30.6001) // 1)

    d = int((j2 - j4 - ((j5 * 30.6001) // 1)) // 1)
    m = int((j5 - 1) // 1)
    if (m > 12) :
      m -= 12
    
    y = int((j3 - 4715) // 1)
    if (m > 2) :
      y -= 1
    
    if (y <= 0) :
      y -= 1

    #//
    #// get time of day from day fraction
    #//
    hr = int((dayfrac * 24.0) // 1)
    mn = int(((dayfrac * 24.0 - hr) * 60.0) // 1)
    f = ((dayfrac * 24.0 - hr) * 60.0 - mn) * 60.0
    sc = (f // 1)
    f -= sc
    if (f > 0.5) :
      sc += 1

    return (snDate(y, m, d, hr, mn, sc))
# Out:
#   File "<ipython-input-100-51353f5dfeef>", line 12
#     j1 = intgr + 1 + tmp - int((0.25 * tmp) // 1)
#      ^
# SyntaxError: invalid syntax

# %%
"""
/*--------------------------------------------------------*/
/*               Suresh's  Jatakam - classes              */
/*  Python code : 2020-11-30                              */
/*--------------------------------------------------------*/
package snMobileJatak.sn_Jatak.snClasses.snBasic;
//package snBasic;
/*--------------------------------------------------------*/
"""
#!pip3 install multipledispatch 
from multipledispatch import dispatch  

class snDate :

  CC, YY, yy, mm, dd, hh, mt, ss = 0, 0, 0, 0, 0, 0, 0, 0

  
  #constructor
  @dispatch(int, int, int, int, int, int)
  def __init__(self, y1, m1, d1, h1, mt1, s1) :
    yy = y1
    YY = yy % 100
    self.yy = y1
    self.mm = m1
    self.dd = d1
    self.hh = h1
    self.mt = mt1
    self.ss = s1
    self.YY = YY
    self.CC = (yy - YY)

  @classmethod
  @dispatch(int, int, int, int, int, int)
  def snDate(cls, y1, m1, d1, h1, mt1, s1) :
    cls.yy = y1
    cls.mm = m1
    cls.dd = d1
    cls.hh = h1
    cls.mt = mt1
    cls.ss = s1
    cls.YY = cls.yy % 100
    cls.CC = cls.yy - cls.YY

  @classmethod
  @dispatch(int, int, int)
  def snDate(cls, y1, m1, d1) :
    cls.yy = y1;
    cls.mm = m1;
    cls.dd = d1;
    cls.YY = cls.yy % 100;
    cls.CC = cls.yy - cls.YY;


  @classmethod
  #@dispatch(class)
  def snDate(cls, d) :
    cls.yy = d.yy;
    cls.mm = d.mm;
    cls.dd = d.dd; 
    cls.YY = cls.yy % 100;
    cls.CC = cls.yy - cls.YY;


  @classmethod
  @dispatch(int)
  def snDate(cls, jd) :
    #long a, l, y, m, d;
    y = int(jd / 365.25)
    a = y / 100;
    jd -= (365 * y + y / 4 + 2 - a + a / 4)
    m = int((jd / 30.6) - 1)
    l = int(30.6 * (float(m + 1)))
    jd -= l
    d = jd
    cls.yy = y
    cls.mm = m
    cls.dd = d
    cls.YY = (cls.yy % 100)
    cls.CC = (cls.yy - cls.YY)

  @classmethod
  @dispatch(float)
  def snDate(cls, JD) :
    sD = cls.JD2CAL(JD)
    cls.yy = sD.yy
    cls.mm = sD.mm
    cls.dd = sD.dd
    cls.YY = sD.YY
    cls.CC = sD.CC
    cls.hh = sD.hh
    cls.mt = sD.mt
    cls.ss = sD.ss

  @classmethod
  def dmy(cls) :
    return ('{}/{}/{}'.format(cls.dd, cls.mm, cls.yy))

  @classmethod
  def ymd(cls) :
    return ('{}/{}/{}'.format("{} Yrs {} mths {} days", cls.yy, cls.mm, cls.dd))


  @classmethod
  def years(cls) :
    return (float(cls.yy) + (float(cls.mm) + float(cls.dd) / 30.0) / 12.0)

  @staticmethod
  @dispatch(int, int, int)
  def jd(d, m, y) :
    #long a, j, l;
    #float b;
    if (m < 3) :
      m += 12
      y -= 1
    a = int(y / 100);
    b = 30.6 * (float(m + 1))
    l = int(b);
    j = int(365 * y + y / 4 + l + 2 - a + a / 4 + d)
    return (j)

  @staticmethod
  #@dispatch(snDate, snDate)
  def datediff(d1, d2) :
    '''
    /*
    long ld1, ld2;
    ld1 = jd(d1.dd, d1.mm, d1.yy);
    ld2 = jd(d2.dd, d2.mm, d2.yy);
     */'''
    #double ld1, ld2;
    ld1 = float(JD(d1.yy, d1.mm, d1.dd, 12, 0, 0))
    ld2 = float(JD(d2.yy, d2.mm, d2.dd, 12, 0, 0))
    return int(ld1 - ld2)


  @staticmethod
  #@dispatch(snDate, snDate)
  def dateDiff(d1, d2) :
    x = snDate(d1)
    #long ld, xx;
    ld = datediff(d1, d2);
    #//System.out.println(" Date Difference :--------->"+d1.dmy() +" "+ d2.dmy());
    x.yy = int(ld / 365)
    #//ld = Math.abs(ld);
    xx = (abs(ld) - abs(x.yy) * 365)
    x.mm = int(xx / 30)
    x.dd = int(xx - x.mm * 30)
    if x.dd >= 30 :
      x.dd = 0
      x.mm += 1
    if x.mm >= 12 :
      x.mm = 0
      x.yy += 1 
    #//System.out.println(x.dmy());
    return (x)


  @staticmethod
  #@dispatch(snDate, int)
  def dateAdd(d1, dadd) :
    '''
    /*
    double ld1;
    ld1 = JD(d1.yy, d1.mm, d1.dd,12,0,0);
    ld1 = ld1 + dadd;
    return (new snDate(ld1));
     */
     '''
    return (snDate(dadd + snDate.JD(d1.yy, d1.mm, d1.dd, 12, 0, 0)))


  @staticmethod
  @dispatch(float)
  def Fix(x) :
   return (int(x))



  @staticmethod
  @dispatch(int, int, int, int, int, float, float)
  def day2000(year, month, day, hour,
         min, sec, greg) :
    #// Returns days before J 2000.0 given date in Gregorian calendar
    #// (greg = 1) or Julian calendar (greg = 0)
    #double a;
    #int b;
    a = 10000.0 * year + 100.0 * month + day;
    if (month <= 2) :
      month += 12;
      year -= 1;
    if (greg == 0) :
      b = -2 + Fix((year + 4716) / 4) - 1179
    else :
      b = Fix(year / 400) - Fix(year / 100) + Fix(year / 4)
    a = 365.0 * year - 730548.5;
    return float(a + b + Fix(30.6001 * (month + 1)) + day +
        (hour + month / 60.0 + sec / 3600.0) / 24.0)


  @staticmethod
  @dispatch(int, int, int, int, int, float)
  def JD(y, m, d, h, mn, s) :
    #// Provide y = negative y  if Era is Before Common Era (BCE)
    #long jy, ja, jm;    //scratch

    era = "CE"      # Common Era

    if (y == 0) :
      print("There is no year 0 in the Julian system!")
      return -1
    else :
      if (y < 0) :
        era = "BCE"    # Before Common Era
        y = -y
    
    if (y == 1582 and m == 10 and d > 4 and d < 15) :
      print("The dates 5 through 14 October, 1582, do not exist in the Gregorian system!")
      return -2
    
    # //  if( y < 0 )  ++y;
    if (era == "BCE") :
      y = -y + 1
    
    if (m > 2) :
      jy = y
      jm = m + 1
    else :
      jy = y - 1
      jm = m + 13

    intgr = int((((365.25 * jy) // 1) + ((30.6001 * jm) // 1) + d + 1720995) // 1)

    #//check for switch to Gregorian calendar
    gregcal = 15 + 31 * (10 + 12 * 1582)
    if (d + 31 * (m + 12 * y) >= gregcal) : 
      ja = int((0.01 * jy) // 1)
      intgr += 2 - ja + int((0.25 * ja) // 1) 
  

    #//correct for half-day offset
    dayfrac = float(h) / 24.0 - 0.5
    if (dayfrac < 0.0) :
      dayfrac += 1.0
      intgr -= 1
    

    #//now set the fraction of a day
    frac = dayfrac + (float(mn) + float(s) / 60.0) / 60.0 / 24.0;

    #//round to nearest second
    jd0 = (float(intgr) + frac) * 100000
    jd = int(jd0 // 1)
    if (jd0 - jd > 0.5) :
      jd += 1
    
    return float(jd / 100000) 



  '''
  //-----------------------------------------------------------------------------
  // convert Julian date to calendar date
  // (algorithm adopted from Press et al.)
  //-----------------------------------------------------------------------------
  '''
  @staticmethod
  @dispatch(float)
  def JD2CAL(jd) :
    #long j1, j2, j3, j4, j5;      //scratch

    #//
    #// get the date from the Julian day number
    #//
    intgr = int(jd // 1)
    frac = jd - intgr
    gregjd = 2299161
    if (intgr >= gregjd) :      # //Gregorian calendar correction
      tmp = int((((intgr - 1867216) - 0.25) // 1) / 36524.25)
      j1 = intgr + 1 + tmp - int((0.25 * tmp) // 1)
    else :
      j1 = intgr
  
    #//correction for half day offset
    dayfrac = frac + 0.5
    if (dayfrac >= 1.0) :
      dayfrac -= 1.0
      j1 += 1

    j2 = j1 + 1524
    j3 = int((6680.0 + ((j2 - 2439870) - 122.1) / 365.25) // 1)
    j4 = int((j3 * 365.25) // 1)
    j5 = int(((j2 - j4) / 30.6001) // 1)

    d = int((j2 - j4 - ((j5 * 30.6001) // 1)) // 1)
    m = int((j5 - 1) // 1)
    if (m > 12) :
      m -= 12
    
    y = int((j3 - 4715) // 1)
    if (m > 2) :
      y -= 1
    
    if (y <= 0) :
      y -= 1

    #//
    #// get time of day from day fraction
    #//
    hr = int((dayfrac * 24.0) // 1)
    mn = int(((dayfrac * 24.0 - hr) * 60.0) // 1)
    f = ((dayfrac * 24.0 - hr) * 60.0 - mn) * 60.0
    sc = (f // 1)
    f -= sc
    if (f > 0.5) :
      sc += 1

    return (snDate(y, m, d, hr, mn, sc))
